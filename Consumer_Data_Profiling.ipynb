# %% [markdown]
# <a href="https://colab.research.google.com/github/getnkit/Data-Pipeline-on-GCP-for-Consumer-Financial-Complaints-Analysis/blob/main/Consumer_Data_Profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mounting Google Drive in Colab

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #Importing Required Library

# %%
import pandas as pd

# %% [markdown]
# #Loading Dataset into Colab

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Consumer_Financial_Complaints.csv"
consumer_data = pd.read_csv(path)

path = "/content/drive/MyDrive/Colab Notebooks/State_name.csv"
state_name = pd.read_csv(path)

# %% [markdown]
# #Data Profiling
# Data profiling is the process of reviewing and cleansing data to better understand how it’s structured and maintain data quality standards.

# %%
consumer_data
# Out:
#       Date received           Product                            Sub-product  \
# 0        12/24/2014          Mortgage            Conventional fixed mortgage
# 1        12/24/2014       Credit card                                    NaN
# 2        12/24/2014   Debt collection                          I do not know
# 3        12/24/2014     Consumer Loan                          Vehicle lease
# 4        12/24/2014          Mortgage                         Other mortgage
# ...             ...               ...                                    ...
# 99995    04/24/2014   Debt collection                          I do not know
# 99996    04/24/2014   Debt collection                            Credit card
# 99997    04/24/2014   Debt collection  Other (i.e. phone, health club, etc.)
# 99998    04/24/2014          Mortgage            Conventional fixed mortgage
# 99999    04/24/2014  Credit reporting                                    NaN
#
# ...

# %%
# Chronologically sort the data into a user-friendly format
df = pd.DataFrame(consumer_data)
df['Date received'] = pd.to_datetime(df['Date received'], format='%m/%d/%Y')
df['Date sent to company'] = pd.to_datetime(df['Date sent to company'], format='%m/%d/%Y')
consumer_data_asc = df.sort_values(by=['Date received', 'Date sent to company', 'Complaint ID'], ascending=True)
consumer_data_asc
# Out:
#       Date received           Product                            Sub-product  \
# 99901    2014-04-24       Credit card                                    NaN
# 99955    2014-04-24  Credit reporting                                    NaN
# 99997    2014-04-24   Debt collection  Other (i.e. phone, health club, etc.)
# 99965    2014-04-24   Debt collection  Other (i.e. phone, health club, etc.)
# 99899    2014-04-24  Credit reporting                                    NaN
# ...             ...               ...                                    ...
# 3        2014-12-24     Consumer Loan                          Vehicle lease
# 0        2014-12-24          Mortgage            Conventional fixed mortgage
# 1        2014-12-24       Credit card                                    NaN
# 4        2014-12-24          Mortgage                         Other mortgage
# 2        2014-12-24   Debt collection                          I do not know
#
# ...

# %%
# Generating Basic Information of the data
consumer_data_asc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 99901 to 2
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date received                 100000 non-null  datetime64[ns]
#  1   Product                       100000 non-null  object
#  2   Sub-product                   70436 non-null   object
#  3   Issue                         100000 non-null  object
#  4   Sub-issue                     47416 non-null   object
#  5   Consumer complaint narrative  0 non-null       float64
#  6   Company public response       108 non-null     object
#  7   Company                       100000 non-null  object
#  8   State code                    99234 non-null   object
#  9   ZIP code                      99231 non-null   object
#  10  Tags                          14724 non-null   object
#  11  Consumer consent provided?    0 non-null       float64
# ...

# %%
# Summarize the descriptive statistics of the data
consumer_data_asc.describe(include='all')
# Out:
#                         Date received   Product     Sub-product  \
# count                          100000    100000           70436
# unique                            NaN        12              46
# top                               NaN  Mortgage  Other mortgage
# freq                              NaN     27480            9499
# mean    2014-08-22 16:50:31.199999744       NaN             NaN
# min               2014-04-24 00:00:00       NaN             NaN
# 25%               2014-06-25 00:00:00       NaN             NaN
# 50%               2014-08-21 00:00:00       NaN             NaN
# 75%               2014-10-21 00:00:00       NaN             NaN
# max               2014-12-24 00:00:00       NaN             NaN
# std                               NaN       NaN             NaN
#
#                                          Issue         Sub-issue  \
# count                                   100000             47416
# ...

# %%
# Computing Total No. of Missing Values
consumer_data_asc.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})
# Out:
#                               Total No. of Missing Values
# Date received                                           0
# Product                                                 0
# Sub-product                                         29564
# Issue                                                   0
# Sub-issue                                           52584
# Consumer complaint narrative                       100000
# Company public response                             99892
# Company                                                 0
# State code                                            766
# ZIP code                                              769
# Tags                                                85276
# Consumer consent provided?                         100000
# Submitted via                                           0
# Date sent to company                                    0
# Company response to consumer                            0
# ...

# %%
# Checking Duplicate Records
consumer_data_asc[consumer_data_asc.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date received, Product, Sub-product, Issue, Sub-issue, Consumer complaint narrative, Company public response, Company, State code, ZIP code, Tags, Consumer consent provided?, Submitted via, Date sent to company, Company response to consumer, Timely response?, Consumer disputed?, Complaint ID]
# Index: []

# %%
state_name
# Out:
#    State abbreviation            State name
# 0                  AK                Alaska
# 1                  AL               Alabama
# 2                  AR              Arkansas
# 3                  AZ               Arizona
# 4                  CA            California
# 5                  CO              Colorado
# 6                  CT           Connecticut
# 7                  DC  District of Columbia
# 8                  DE              Delaware
# 9                  FL               Florida
# 10                 GA               Georgia
# 11                 HI                Hawaii
# 12                 IA                  Iowa
# 13                 ID                 Idaho
# 14                 IL              Illinois
# 15                 IN               Indiana
# 16                 KS                Kansas
# 17                 KY              Kentucky
# 18                 LA             Louisiana
# 19                 MA         Massachusetts
# ...

# %%
# Checking Duplicate Records
state_name[state_name.duplicated()]
# Out:
# Empty DataFrame
# Columns: [State abbreviation, State name]
# Index: []

# %% [markdown]
# #Save to CSV

# %%
consumer_data_asc.to_csv("consumer_data_profiled.csv", index=False)

state_name.to_csv("state_name_profiled.csv", index=False)
