# %% [markdown]
# <a href="https://colab.research.google.com/github/getnkit/Automated-Data-Pipeline-for-Financial-Analysis/blob/main/Consumer_Financial_Complaints_profiled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mounting Google Drive in Colab

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #Importing Required Libraries

# %%
import pandas as pd

# %% [markdown]
# #Loading Dataset into Colab

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Consumer_Financial_Complaints.csv"
consumer_data = pd.read_csv(path)

path = "/content/drive/MyDrive/Colab Notebooks/State_name.csv"
state_name = pd.read_csv(path)

# %% [markdown]
# #Data Profiling

# %% [markdown]
# Data profiling is the process of examining and analyzing a dataset to understand its structure, content, and quality.

# %%
consumer_data
# Out:
#         Date received                                            Product  \
# 0           5/10/2019                        Checking or savings account
# 1           5/10/2019                        Checking or savings account
# 2           5/10/2019                                    Debt collection
# 3           5/10/2019  Credit reporting, credit repair services, or o...
# 4           5/10/2019                        Checking or savings account
# ...               ...                                                ...
# 1048570    04/24/2014                                    Debt collection
# 1048571    04/24/2014                                    Debt collection
# 1048572    04/24/2014                                    Debt collection
# 1048573    04/24/2014                                           Mortgage
# 1048574    04/24/2014                                   Credit reporting
#
#                                    Sub-product  \
# 0                             Checking account
# 1             Other banking product or service
# 2                             Payday loan debt
# 3                             Credit reporting
# 4                             Checking account
# ...                                        ...
# 1048570                          I do not know
# 1048571                            Credit card
# 1048572  Other (i.e. phone, health club, etc.)
# 1048573            Conventional fixed mortgage
# 1048574                                    NaN
#
#                                             Issue  \
# 0                             Managing an account
# 1                             Managing an account
# 2                           Communication tactics
# 3            Incorrect information on your report
# 4                             Managing an account
# ...                                           ...
# 1048570     Cont'd attempts collect debt not owed
# 1048571        False statements or representation
# 1048572        False statements or representation
# 1048573  Loan servicing, payments, escrow account
# 1048574  Credit reporting company's investigation
#
#                                             Sub-issue  \
# 0                   Problem using a debit or ATM card
# 1                            Deposits and withdrawals
# 2                          Frequent or repeated calls
# 3        Old information reappears or never goes away
# 4                                      Banking errors
# ...                                               ...
# 1048570                              Debt is not mine
# 1048571             Attempted to collect wrong amount
# 1048572             Attempted to collect wrong amount
# 1048573                                           NaN
# 1048574             Problem with statement of dispute
#
#         Consumer complaint narrative Company public response  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
# ...                              ...                     ...
# 1048570                          NaN                     NaN
# 1048571                          NaN                     NaN
# 1048572                          NaN                     NaN
# 1048573                          NaN                     NaN
# 1048574                          NaN                     NaN
#
#                                    Company State code ZIP code  \
# 0                NAVY FEDERAL CREDIT UNION         FL    328XX
# 1            BOEING EMPLOYEES CREDIT UNION         WA    98204
# 2               CURO Intermediate Holdings         TX    751XX
# 3           Ad Astra Recovery Services Inc         LA    708XX
# 4                      ALLY FINANCIAL INC.         AZ    85205
# ...                                    ...        ...      ...
# 1048570  Professional Debt Mediation, Inc.         FL    32207
# 1048571                   Hunt & Henriques         CA    959XX
# 1048572                          HOVG, LLC         MN    563XX
# 1048573                     CITIBANK, N.A.         MA    015XX
# 1048574                      EQUIFAX, INC.         MD    21213
#
#                    Tags Consumer consent provided? Submitted via  \
# 0        Older American                        NaN           Web
# 1                   NaN                        NaN      Referral
# 2                   NaN                        NaN           Web
# 3                   NaN                        NaN           Web
# 4                   NaN                        NaN   Postal mail
# ...                 ...                        ...           ...
# 1048570             NaN                        NaN         Phone
# 1048571             NaN                        NaN           Web
# 1048572             NaN                        NaN           Web
# 1048573             NaN                        NaN           Web
# 1048574             NaN                        NaN           Web
#
#         Date sent to company Company response to consumer Timely response?  \
# 0                  5/10/2019                  In progress              Yes
# 1                  5/10/2019      Closed with explanation              Yes
# 2                  5/10/2019      Closed with explanation              Yes
# 3                  5/10/2019      Closed with explanation              Yes
# 4                  5/10/2019                  In progress              Yes
# ...                      ...                          ...              ...
# 1048570           04/29/2014      Closed with explanation              Yes
# 1048571             5/1/2014  Closed with monetary relief              Yes
# 1048572           04/23/2014      Closed with explanation              Yes
# 1048573           04/24/2014      Closed with explanation              Yes
# 1048574           04/24/2014      Closed with explanation              Yes
#
#         Consumer disputed?  Complaint ID
# 0                      NaN       3238275
# 1                      NaN       3238228
# 2                      NaN       3237964
# 3                      NaN       3238479
# 4                      NaN       3238460
# ...                    ...           ...
# 1048570                 No        824288
# 1048571                 No        823526
# 1048572                 No        823152
# 1048573                 No        823375
# 1048574                 No        824543
#
# [1048575 rows x 18 columns]

# %%
#Chronologically sort the data into a user-friendly format
df = pd.DataFrame(consumer_data_asc)
df['Date received'] = pd.to_datetime(df['Date received'], format='%m/%d/%Y')
consumer_data_asc = df.sort_values(by=['Date received', 'Date sent to company', 'Complaint ID'], ascending=True)
consumer_data_asc
# Out:
#         Date received                                            Product  \
# 1048476    2014-04-24                                        Credit card
# 1048530    2014-04-24                                   Credit reporting
# 1048572    2014-04-24                                    Debt collection
# 1048540    2014-04-24                                    Debt collection
# 1048474    2014-04-24                                   Credit reporting
# ...               ...                                                ...
# 12         2019-05-10                                    Debt collection
# 3          2019-05-10  Credit reporting, credit repair services, or o...
# 8          2019-05-10                                    Debt collection
# 6          2019-05-10                                    Debt collection
# 16         2019-05-10                                    Debt collection
#
#                                    Sub-product  \
# 1048476                                    NaN
# 1048530                                    NaN
# 1048572  Other (i.e. phone, health club, etc.)
# 1048540  Other (i.e. phone, health club, etc.)
# 1048474                                    NaN
# ...                                        ...
# 12                            Payday loan debt
# 3                             Credit reporting
# 8                                   Other debt
# 6                                   Other debt
# 16                                Medical debt
#
#                                             Issue  \
# 1048476     Identity theft / Fraud / Embezzlement
# 1048530    Incorrect information on credit report
# 1048572        False statements or representation
# 1048540           Disclosure verification of debt
# 1048474  Unable to get credit report/credit score
# ...                                           ...
# 12              Attempts to collect debt not owed
# 3            Incorrect information on your report
# 8               Attempts to collect debt not owed
# 6               Attempts to collect debt not owed
# 16                          Communication tactics
#
#                                             Sub-issue  \
# 1048476                                           NaN
# 1048530                                Account status
# 1048572             Attempted to collect wrong amount
# 1048540          Right to dispute notice not received
# 1048474        Problem getting report or credit score
# ...                                               ...
# 12                                  Debt is not yours
# 3        Old information reappears or never goes away
# 8                                       Debt was paid
# 6                                   Debt is not yours
# 16                         Frequent or repeated calls
#
#         Consumer complaint narrative Company public response  \
# 1048476                          NaN                     NaN
# 1048530                          NaN                     NaN
# 1048572                          NaN                     NaN
# 1048540                          NaN                     NaN
# 1048474                          NaN                     NaN
# ...                              ...                     ...
# 12                               NaN                     NaN
# 3                                NaN                     NaN
# 8                                NaN                     NaN
# 6                                NaN                     NaN
# 16                               NaN                     NaN
#
#                                         Company State code ZIP code  \
# 1048476       CAPITAL ONE FINANCIAL CORPORATION         NY    13027
# 1048530  TRANSUNION INTERMEDIATE HOLDINGS, INC.         OR    97702
# 1048572                               HOVG, LLC         MN    563XX
# 1048540                              Jomax, LLC         NY    11105
# 1048474                           EQUIFAX, INC.         IN    46227
# ...                                         ...        ...      ...
# 12               Ad Astra Recovery Services Inc         TX      NaN
# 3                Ad Astra Recovery Services Inc         LA    708XX
# 8                 Diversified Consultants, Inc.         SC    296XX
# 6                 Diversified Consultants, Inc.         TX      NaN
# 16            MERCANTILE ADJUSTMENT BUREAU, LLC         NY    14609
#
#                    Tags Consumer consent provided? Submitted via  \
# 1048476  Older American                        NaN           Web
# 1048530             NaN                        NaN           Web
# 1048572             NaN                        NaN           Web
# 1048540             NaN                        NaN           Web
# 1048474             NaN                        NaN           Web
# ...                 ...                        ...           ...
# 12                  NaN                        NaN           Web
# 3                   NaN                        NaN           Web
# 8         Servicemember                        NaN           Web
# 6         Servicemember                        NaN           Web
# 16                  NaN                        NaN           Web
#
#         Date sent to company     Company response to consumer  \
# 1048476           04/23/2014  Closed with non-monetary relief
# 1048530           04/23/2014  Closed with non-monetary relief
# 1048572           04/23/2014          Closed with explanation
# 1048540           04/23/2014                Untimely response
# 1048474           04/23/2014          Closed with explanation
# ...                      ...                              ...
# 12                 5/10/2019          Closed with explanation
# 3                  5/10/2019          Closed with explanation
# 8                  5/10/2019                      In progress
# 6                  5/10/2019                      In progress
# 16                 5/10/2019          Closed with explanation
#
#         Timely response? Consumer disputed?  Complaint ID
# 1048476              Yes                 No        822843
# 1048530              Yes                 No        823108
# 1048572              Yes                 No        823152
# 1048540               No                 No        823173
# 1048474              Yes                 No        823188
# ...                  ...                ...           ...
# 12                   Yes                NaN       3238461
# 3                    Yes                NaN       3238479
# 8                    Yes                NaN       3238545
# 6                    Yes                NaN       3238585
# 16                   Yes                NaN       3238682
#
# [1048575 rows x 18 columns]

# %%
#Generating Basic Information of the data
consumer_data_asc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1048575 entries, 1048476 to 16
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   Date received                 1048575 non-null  datetime64[ns]
#  1   Product                       1048575 non-null  object
#  2   Sub-product                   874198 non-null   object
#  3   Issue                         1048575 non-null  object
#  4   Sub-issue                     699655 non-null   object
#  5   Consumer complaint narrative  383564 non-null   object
#  6   Company public response       449051 non-null   object
#  7   Company                       1048575 non-null  object
#  8   State code                    1031078 non-null  object
#  9   ZIP code                      935181 non-null   object
#  10  Tags                          146542 non-null   object
#  11  Consumer consent provided?    690654 non-null   object
#  12  Submitted via                 1048575 non-null  object
#  13  Date sent to company          1048575 non-null  object
#  14  Company response to consumer  1048568 non-null  object
#  15  Timely response?              1048575 non-null  object
#  16  Consumer disputed?            534721 non-null   object
#  17  Complaint ID                  1048575 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(16)
# memory usage: 152.0+ MB

# %%
#Summarize the descriptive statistics of the data
consumer_data_asc.describe(include='all')
# Out:
#                         Date received  \
# count                         1048575
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2017-02-05 00:01:26.682211328
# min               2014-04-24 00:00:00
# 25%               2015-12-09 00:00:00
# 50%               2017-04-06 00:00:00
# 75%               2018-04-14 00:00:00
# max               2019-05-10 00:00:00
# std                               NaN
#
#                                                   Product       Sub-product  \
# count                                             1048575            874198
# unique                                                 18                76
# top     Credit reporting, credit repair services, or o...  Credit reporting
# freq                                               225978            221652
# mean                                                  NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
# std                                                   NaN               NaN
#
#                                        Issue  \
# count                                1048575
# unique                                   164
# top     Incorrect information on your report
# freq                                  134338
# mean                                     NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
# std                                      NaN
#
#                                   Sub-issue  \
# count                                699655
# unique                                  218
# top     Information belongs to someone else
# freq                                  59168
# mean                                    NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
# std                                     NaN
#
#                              Consumer complaint narrative  \
# count                                              383564
# unique                                             366931
# top     There are many mistakes appear in my report wi...
# freq                                                  978
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                                   Company public response        Company  \
# count                                              449051        1048575
# unique                                                 10           5152
# top     Company has responded to the consumer and the ...  EQUIFAX, INC.
# freq                                               311844         107124
# mean                                                  NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
# std                                                   NaN            NaN
#
#        State code ZIP code           Tags Consumer consent provided?  \
# count     1031078   935181         146542                     690654
# unique         63    20941              3                          4
# top            CA    300XX  Servicemember           Consent provided
# freq       139761     7202          75505                     383885
# mean          NaN      NaN            NaN                        NaN
# min           NaN      NaN            NaN                        NaN
# 25%           NaN      NaN            NaN                        NaN
# 50%           NaN      NaN            NaN                        NaN
# 75%           NaN      NaN            NaN                        NaN
# max           NaN      NaN            NaN                        NaN
# std           NaN      NaN            NaN                        NaN
#
#        Submitted via Date sent to company Company response to consumer  \
# count        1048575              1048575                      1048568
# unique             6                 1843                            6
# top              Web             9/8/2017      Closed with explanation
# freq          816643                 3387                       836626
# mean             NaN                  NaN                          NaN
# min              NaN                  NaN                          NaN
# 25%              NaN                  NaN                          NaN
# 50%              NaN                  NaN                          NaN
# 75%              NaN                  NaN                          NaN
# max              NaN                  NaN                          NaN
# std              NaN                  NaN                          NaN
#
#        Timely response? Consumer disputed?  Complaint ID
# count           1048575             534721  1.048575e+06
# unique                2                  2           NaN
# top                 Yes                 No           NaN
# freq            1021352             435259           NaN
# mean                NaN                NaN  2.269636e+06
# min                 NaN                NaN  8.202530e+05
# 25%                 NaN                NaN  1.689888e+06
# 50%                 NaN                NaN  2.421887e+06
# 75%                 NaN                NaN  2.876756e+06
# max                 NaN                NaN  3.238682e+06
# std                 NaN                NaN  7.005562e+05

# %%
#Computing Total No. of Missing Values
consumer_data_asc.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})
# Out:
#                               Total No. of Missing Values
# Date received                                           0
# Product                                                 0
# Sub-product                                        174377
# Issue                                                   0
# Sub-issue                                          348920
# Consumer complaint narrative                       665011
# Company public response                            599524
# Company                                                 0
# State code                                          17497
# ZIP code                                           113394
# Tags                                               902033
# Consumer consent provided?                         357921
# Submitted via                                           0
# Date sent to company                                    0
# Company response to consumer                            7
# Timely response?                                        0
# Consumer disputed?                                 513854
# Complaint ID                                            0

# %%
#Checking Duplicate Records
consumer_data_asc[consumer_data_asc.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date received, Product, Sub-product, Issue, Sub-issue, Consumer complaint narrative, Company public response, Company, State code, ZIP code, Tags, Consumer consent provided?, Submitted via, Date sent to company, Company response to consumer, Timely response?, Consumer disputed?, Complaint ID]
# Index: []

# %%
state_name
# Out:
#               State name
# 0                 Alaska
# 1                Alabama
# 2               Arkansas
# 3                Arizona
# 4             California
# 5               Colorado
# 6            Connecticut
# 7   District of Columbia
# 8               Delaware
# 9                Florida
# 10               Georgia
# 11                Hawaii
# 12                  Iowa
# 13                 Idaho
# 14              Illinois
# 15               Indiana
# 16                Kansas
# 17              Kentucky
# 18             Louisiana
# 19         Massachusetts
# 20              Maryland
# 21                 Maine
# 22              Michigan
# 23             Minnesota
# 24              Missouri
# 25           Mississippi
# 26               Montana
# 27       North Carolina
# 28         North Dakota
# 29             Nebraska
# 30        New Hampshire
# 31           New Jersey
# 32           New Mexico
# 33               Nevada
# 34             New York
# 35                 Ohio
# 36             Oklahoma
# 37               Oregon
# 38          Pennsylvania
# 39         Rhode Island
# 40       South Carolina
# 41         South Dakota
# 42            Tennessee
# 43                Texas
# 44                 Utah
# 45             Virginia
# 46              Vermont
# 47           Washington
# 48            Wisconsin
# 49        West Virginia
# 50               Wyoming

# %%
#Checking Duplicate Records
state_name[state_name.duplicated()]
# Out:
# Empty DataFrame
# Columns: [State name]
# Index: []

# %% [markdown]
# #Save to CSV

# %%
consumer_data_asc.to_csv("consumer_data_profiled.csv", index=False)

state_name.to_csv("state_name_profiled.csv", index=False)
